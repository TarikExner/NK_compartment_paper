# %%
import warnings
warnings.filterwarnings(
    action='ignore',
    category=FutureWarning
)

# %%
import os

import FACSPy as fp
import scanpy as sc

import figure_config as cfg

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
import seaborn as sns
from matplotlib.gridspec import GridSpec
from matplotlib import gridspec

from matplotlib.figure import Figure
from matplotlib.axes import Axes
import matplotlib.patches as mpatches
from matplotlib.legend_handler import HandlerBase

# %%
cd4 = fp.read_dataset(cfg.data_input, "dataset_CD4T_preprocessed")
cd4.uns["metadata"].dataframe["group"] = cd4.uns["metadata"].dataframe["diag_main"]
cd4.uns["metadata"].dataframe["organ_diag_plot"] = [
    f"{diag}: {organ}" for organ, diag
    in zip(cd4.uns["metadata"].dataframe["organ"].tolist(), cd4.uns["metadata"].dataframe["diag_main"].tolist())
]

# %%
fp.settings.default_gate = "CD4_T_cells"
fp.settings.default_layer = "transformed"
fp.tl.mfi(cd4, layer = "compensated")
fp.tl.pca_samplewise(cd4)
# Out:
# C:\Users\tarik\anaconda3\envs\FACSPypeline\lib\site-packages\FACSPy\tools\_utils.py:430: InsufficientSampleNumberWarning: 'The gate root/all_cells/live/CD45+/PBMC/CD19neg,_CD14neg/NK has only members in 1 samples, which is insufficient for the dimensionality reduction with 3 components. The coordinates of the missing components are set to NaN.'
#   warnings.warn(InsufficientSampleNumberWarning._construct_message(**warnings_params),

# %%
#################
### FIGURE S6 ###
#################

fp.settings.default_gate = "CD4_T_cells"
fp.settings.default_layer = "compensated"
fig = plt.figure(layout = "constrained", figsize = (cfg.FIGURE_WIDTH_FULL, cfg.FIGURE_HEIGHT_FULL))
gs = gridspec.GridSpec(ncols = 6,
                       nrows = 5,
                       figure = fig)
plot_params = {
    "adata": cd4,
    "show": False,
    "groupby": "organ_diag_plot"
}

marker_count = 0
markers = cd4.var_names.tolist()
markers = [marker for marker in markers if not marker in ["Zombie_NIR", "CD66b"]]
for i in range(6):
    for j in range(5):
        marker = fig.add_subplot(gs[j,i])
        marker_plot = fp.pl.mfi(
            **plot_params,
            marker = markers[marker_count],
            ax = marker
        )
        ymin, ymax = marker_plot.get_ylim()
        marker_plot.set_ylim(ymin, ymax*1.1)
        cfg._adjust_xlabels(marker_plot)
        marker_plot.set_ylabel(f"median fluorescence\nintensity [AFU]", fontsize = cfg.AXIS_LABEL_SIZE)
        cfg._adjust_ylabels(marker_plot)
        marker_plot.tick_params(size = cfg.AXIS_LABEL_SIZE, pad = 0)
        marker_plot.set_title(markers[marker_count], fontsize = cfg.TITLE_SIZE)
        marker = fig.add_subplot(marker_plot)
        marker_count += 1
        if marker_count == len(markers):
            break

plt.savefig(f"{cfg.figure_output}FigureS8.pdf", dpi = 300, bbox_inches ="tight")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\tarik\RGBLab\Franca\NK_spectral_full\code\figure_config.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize = AXIS_LABEL_SIZE)
